# %% [markdown]
# <a href="https://colab.research.google.com/github/ornellajogi/Team-3-WoTech-July-6-2024-/blob/main/July_6_(WoTech)_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We have pandas series and pandas framework

# %%
import pandas as pd

# %%
data_list = [1,2,3,4,5]
print(data_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
series_from_list = pd.Series(data_list)
print(series_from_list)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dataframe_from_list = pd.DataFrame(data_list)
print(dataframe_from_list)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ### Pandas Series from DataFrame

# %%
data_dict = {'A': 10, 'B': 20, 'C': 30, 'D': 40, 'E': 50}

dataframe_from_dict = pd.Series(data_dict)
print(dataframe_from_dict)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
csv_data = "1,2,3,4,5" #string
csv_data.split(',') #split the string into a list
# Out:
# ['1', '2', '3', '4', '5']

# %%
series_from_list_split = pd.Series(csv_data.split(','))
print(series_from_list_split)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: object

# %% [markdown]
# DataFrames![image.png](data:image/png;base64,...)
#
#  lists are accessed by index and dictionaries with a key
#
#  lists with [] and dictionaries with {}

# %%
#nested list
data_list = [
    ['John', 30, 68.5, True, 95.5],
    ['Alice', 25, 63.2, False, 88.0],
    ['Bob', 35, 71.0, True, 76.5],
    ['Eve', 28, 65.8, False, 92.0],
    ['Charlie', 40, 72.3, False, 87.5]
]

pd.DataFrame(data_list)
#get default indices and columns
# Out:
#          0   1     2      3     4
# 0     John  30  68.5   True  95.5
# 1    Alice  25  63.2  False  88.0
# 2      Bob  35  71.0   True  76.5
# 3      Eve  28  65.8  False  92.0
# 4  Charlie  40  72.3  False  87.5

# %%
column_names = ['Name', 'Age', 'Weight', 'Is Student', 'Score']
pd.DataFrame(data_list, columns = column_names)
#get default indices and columns
# Out:
#       Name  Age  Weight  Is Student  Score
# 0     John   30    68.5        True   95.5
# 1    Alice   25    63.2       False   88.0
# 2      Bob   35    71.0        True   76.5
# 3      Eve   28    65.8       False   92.0
# 4  Charlie   40    72.3       False   87.5

# %%
df = pd.read_csv('/content/transaction_dataset.csv') # we have read in

# %%
df.head()
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  20/10/2002               35.47
# 1        26381  Michelle     Phelps    NaN  24/10/1985             2552.72
# 2       305449     Jacob   Williams      M  25/10/1981              115.97
# 3       988259    Nathan     Snyder      M  26/10/1977               11.31
# 4       764762   Crystal      Knapp      F  02/11/1951               62.21
#
#          Date               Merchant Name     Category
# 0  03/04/2023               Smith-Russell     Cosmetic
# 1  17/07/2023      Peck, Spence and Young       Travel
# 2  20/09/2023                  Steele Inc     Clothing
# 3  11/01/2023  Wilson, Wilson and Russell     Cosmetic
# 4  13/06/2023               Palmer-Hinton  Electronics

# %%
df.tail() #last 5 rows of df
# Out:
#        Customer ID       Name   Surname Gender   Birthdate  \
# 49995       891845  Christine     Leach      F  21/10/1997
# 49996       800560       Anna     Allen      F  21/10/1999
# 49997       133285     Nicole  Franklin      M  26/10/1979
# 49998       616122      Maria    Keller      M  25/10/1981
# 49999       832184      Billy    Walker      F  31/10/1958
#
#        Transaction Amount        Date                 Merchant Name  Category
# 49995              108.74  30/08/2023                 Alexander Ltd    Market
# 49996              133.66  03/05/2023                 Knapp-Calhoun  Cosmetic
# 49997              464.29  12/02/2023  Cantrell, Haynes and Ballard    Market
# 49998              472.57  25/03/2023     Wilson, Jackson and Beard    Market
# 49999              270.67  20/05/2023                     Combs LLC    Market

# %%
#can change how many want
df.head(n=10)
# Out:
#    Customer ID       Name     Surname Gender   Birthdate  Transaction Amount  \
# 0       752858       Sean   Rodriguez      F  20/10/2002               35.47
# 1        26381   Michelle      Phelps    NaN  24/10/1985             2552.72
# 2       305449      Jacob    Williams      M  25/10/1981              115.97
# 3       988259     Nathan      Snyder      M  26/10/1977               11.31
# 4       764762    Crystal       Knapp      F  02/11/1951               62.21
# 5       576539     Monica    Bartlett      F  20/10/2001               99.14
# 6       124681     Thomas        Shaw    NaN  26/10/1976              145.94
# 7       521807     Kelsey        Pena      F  28/10/1968              161.39
# 8       504238     Denise      Porter      M  31/10/1957               77.73
# 9       583532  Alexander  Richardson      F  27/10/1974              142.85
#
#          Date               Merchant Name     Category
# 0  03/04/2023               Smith-Russell     Cosmetic
# ...

# %%
df.shape # nr of rows and columns
# Out:
# (50000, 9)

# %%
df.sample(5) #random sample
# Out:
#        Customer ID      Name   Surname Gender   Birthdate  Transaction Amount  \
# 13839       972418   William     Green      F  01/11/1955               69.05
# 37855       801558      Lisa      Ryan      F  23/10/1990               75.04
# 8666        739030  Jennifer     Brown    NaN  27/10/1974              289.70
# 47292       674588      Jose    Nelson      M  24/10/1985              208.49
# 34953       873539      Gary  Crawford      M  21/10/1996               90.81
#
#              Date                Merchant Name     Category
# 13839  05/04/2023               Jones and Sons   Restaurant
# 37855  07/09/2023                Brandt-Weaver     Cosmetic
# 8666   30/01/2023  Flowers, Alvarez and Conway     Clothing
# 47292  23/09/2023      Stone, Spears and White  Electronics
# 34953  20/06/2023            Davila-Fitzgerald   Restaurant

# %%
df.info() #column names, data types, value count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           50000 non-null  object
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  object
#  7   Merchant Name       50000 non-null  object
#  8   Category            50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
df.describe() #summary stats of integers/floats
# Out:
#         Customer ID  Transaction Amount
# count   50000.00000        50000.000000
# mean   500136.79696          442.119239
# std    288232.43164          631.669724
# min        29.00000            5.010000
# 25%    251191.50000           79.007500
# 50%    499520.50000          182.195000
# 75%    749854.25000          470.515000
# max    999997.00000         2999.880000

# %%
df.describe(include='object') #summary stats incl objects
# Out:
#            Name Surname Gender   Birthdate        Date Merchant Name  \
# count     50000   50000  44953       50000       50000         50000
# unique      690    1000      2          58         287         36939
# top     Michael   Smith      F  01/11/1954  30/06/2023     Smith Ltd
# freq       1167    1095  22713         914         200            69
#
#           Category
# count        50000
# unique           6
# top     Restaurant
# freq          8413

# %%
# How to look at one column
df['Gender']

#on this column we can calc some things
df['Gender'].unique()
# Out:
# array(['F', nan, 'M'], dtype=object)

# %%
df['Gender'] # access column by a name, we can access several columns

df.Gender # accessing column with attribute; we access same column but cant use spaces in column name and can only access 1 column

df.iloc[:, 3] # all rows with :, accessing column with index [row, column]
# Out:
# 0          F
# 1        NaN
# 2          M
# 3          M
# 4          F
#         ...
# 49995      F
# 49996      F
# 49997      M
# 49998      M
# 49999      F
# Name: Gender, Length: 50000, dtype: object

# %%
# value counts

df['Gender'].value_counts() # drops na my default
# Out:
# Gender
# F    22713
# M    22240
# Name: count, dtype: int64

# %%
# value counts

df['Gender'].value_counts(dropna=False) # keep na
# Out:
# Gender
# F      22713
# M      22240
# NaN     5047
# Name: count, dtype: int64

# %%
df.isna() #binary values, True=empty; in binary False = 0, True = 1
# Out:
#        Customer ID   Name  Surname  Gender  Birthdate  Transaction Amount  \
# 0            False  False    False   False      False               False
# 1            False  False    False    True      False               False
# 2            False  False    False   False      False               False
# 3            False  False    False   False      False               False
# 4            False  False    False   False      False               False
# ...            ...    ...      ...     ...        ...                 ...
# 49995        False  False    False   False      False               False
# 49996        False  False    False   False      False               False
# 49997        False  False    False   False      False               False
# 49998        False  False    False   False      False               False
# 49999        False  False    False   False      False               False
#
#         Date  Merchant Name  Category
# 0      False          False     False
# ...

# %%
df.isna().sum()
# Out:
# Customer ID              0
# Name                     0
# Surname                  0
# Gender                5047
# Birthdate                0
# Transaction Amount       0
# Date                     0
# Merchant Name            0
# Category                 0
# dtype: int64

# %%
df.notna().sum()
# Out:
# Customer ID           50000
# Name                  50000
# Surname               50000
# Gender                44953
# Birthdate             50000
# Transaction Amount    50000
# Date                  50000
# Merchant Name         50000
# Category              50000
# dtype: int64

# %%
df.notna().all() #check if all values not empty
# Out:
# Customer ID            True
# Name                   True
# Surname                True
# Gender                False
# Birthdate              True
# Transaction Amount     True
# Date                   True
# Merchant Name          True
# Category               True
# dtype: bool

# %%
### Drop empty values

df.dropna() #did not override existing df
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  20/10/2002
# 2           305449      Jacob   Williams      M  25/10/1981
# 3           988259     Nathan     Snyder      M  26/10/1977
# 4           764762    Crystal      Knapp      F  02/11/1951
# 5           576539     Monica   Bartlett      F  20/10/2001
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  21/10/1997
# 49996       800560       Anna      Allen      F  21/10/1999
# 49997       133285     Nicole   Franklin      M  26/10/1979
# 49998       616122      Maria     Keller      M  25/10/1981
# 49999       832184      Billy     Walker      F  31/10/1958
#
#        Transaction Amount        Date                 Merchant Name  \
# 0                   35.47  03/04/2023                 Smith-Russell
# 2                  115.97  20/09/2023                    Steele Inc
# ...

# %%
df_new_dataframe = df.dropna() # save it in new df

# %%
#how to override existing dataframe?
df.dropna(inplace=True) #specify that want to override existing dataframe

# %%
# Saving the cleaned file
df.to_csv('cleaned_data.csv')
